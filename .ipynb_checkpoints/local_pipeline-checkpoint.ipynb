# %% [markdown]
# # Import Library

# %%
import os
import pandas as pd
from typing import Text

from absl import logging
from tfx.orchestration import metadata, pipeline
from tfx.orchestration.beam.beam_dag_runner import BeamDagRunner

# %% [markdown]
# # Prepocessing

# %%
df = pd.read_csv("news_articles.csv")
df = df.query("text_without_stopwords == text_without_stopwords")
df = df.groupby('label').apply(lambda s: s.sample(500)).reset_index(drop=True)
df = df[["text_without_stopwords", "label"]]
df.to_csv("data/news_articles.csv",index=False)
df
# Out:
#      text_without_stopwords label
# 2046                    NaN  Real
# 2047                    NaN  Real
# 2048                    NaN  Real
# 2049                    NaN  Real
# 2050                    NaN  Real
# 2051                    NaN  Real
# 2052                    NaN  Real
# 2053                    NaN  Real
# 2054                    NaN  Real
# 2055                    NaN  Real
# 2056                    NaN  Real
# 2057                    NaN  Real
# 2058                    NaN  Real
# 2059                    NaN  Real
# 2060                    NaN  Real
# 2061                    NaN  Real
# 2062                    NaN  Real
# 2063                    NaN  Real
# 2064                    NaN  Real
# 2065                    NaN  Real
# 2066                    NaN  Real
# 2067                    NaN  Real
# 2068                    NaN  Real
# 2069                    NaN  Real
# 2070                    NaN  Real
# 2071                    NaN  Real
# 2072                    NaN  Real
# 2073                    NaN  Real
# 2074                    NaN  Real
# 2075                    NaN  Real
# 2076                    NaN  Real
# 2077                    NaN  Real
# 2078                    NaN  Real
# 2079                    NaN  Real
# 2080                    NaN  Real
# 2081                    NaN  Real
# 2082                    NaN  Real
# 2083                    NaN  Real
# 2084                    NaN  Real
# 2085                    NaN  Real
# 2086                    NaN  Real
# 2087                    NaN  Real
# 2088                    NaN  Real
# 2089                    NaN  Real
# 2090                    NaN  Real
# 2091                    NaN  Real
# 2092                    NaN  Real
# 2093                    NaN  Fake
# 2094                    NaN  Fake
# 2095                    NaN   NaN

# %% [markdown]
# # Set Variabel

# %%
PIPELINE_NAME = "gesang_wibawono-pipeline"

DATA_ROOT = "data"
TRANSFORM_MODULE_FILE = "modules/fake_news_transform.py"
TRAINER_MODULE_FILE = "modules/fake_news_trainer.py"

OUTPUT_BASE = "output"
serving_model_dir = os.path.join(OUTPUT_BASE, 'serving_model')
pipeline_root = os.path.join(OUTPUT_BASE, PIPELINE_NAME)
metadata_path = os.path.join(pipeline_root, "metadata.sqlite")

# %% [markdown]
# # Pipeline

# %%
def init_local_pipeline(
    components, pipeline_root: Text
) -> pipeline.Pipeline:
    """
    Main
    """

    logging.info(f"Pipeline root set to: {pipeline_root}")
    beam_args = [
        "--direct_running_mode=multi_processing"
        "----direct_num_workers=0"
    ]

    return pipeline.Pipeline(
        pipeline_name=PIPELINE_NAME,
        pipeline_root=pipeline_root,
        components=components,
        enable_cache=True,
        metadata_connection_config=metadata.sqlite_metadata_connection_config(
            metadata_path
        ),
        eam_pipeline_args=beam_args
    )

# %%
logging.set_verbosity(logging.INFO)

from modules.components import init_components

components = init_components(
    DATA_ROOT,
    transform_module=TRANSFORM_MODULE_FILE,
    trainer_module=TRAINER_MODULE_FILE,
    training_steps=20,
    eval_steps=10,
    serving_model_dir=serving_model_dir,
)

pipeline = init_local_pipeline(components, pipeline_root)
BeamDagRunner().run(pipeline=pipeline)
# Out:
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Pipeline root set to: output\gesang_wibawono-pipeline
# INFO:absl:Generating ephemeral wheel package for 'D:\\learning\\fake-news\\modules\\fake_news_transform.py' (including modules: ['components', 'fake_news_trainer', 'fake_news_transform']).
# INFO:absl:User module package has hash fingerprint version 21b7143bb664e0ef25e97060c4b3d952f2566cbaeebe6b9dcc0ba4cfb2ec4b37.
# INFO:absl:Executing: ['C:\\Users\\BPS\\.conda\\envs\\a443-churn\\python.exe', 'C:\\Users\\BPS\\AppData\\Local\\Temp\\tmpuhbqlwaf\\_tfx_generated_setup.py', 'bdist_wheel', '--bdist-dir', 'C:\\Users\\BPS\\AppData\\Local\\Temp\\tmpxowskk2c', '--dist-dir', 'C:\\Users\\BPS\\AppData\\Local\\Temp\\tmp45rd7r9t']
# INFO:absl:Successfully built user code wheel distribution at 'output\\gesang_wibawono-pipeline\\_wheels\\tfx_user_code_Transform-0.0+21b7143bb664e0ef25e97060c4b3d952f2566cbaeebe6b9dcc0ba4cfb2ec4b37-py3-none-any.whl'; target user module is 'fake_news_transform'.
# INFO:absl:Full user module path is 'fake_news_transform@output\\gesang_wibawono-pipeline\\_wheels\\tfx_user_code_Transform-0.0+21b7143bb664e0ef25e97060c4b3d952f2566cbaeebe6b9dcc0ba4cfb2ec4b37-py3-none-any.whl'
# INFO:absl:Generating ephemeral wheel package for 'D:\\learning\\fake-news\\modules\\fake_news_trainer.py' (including modules: ['components', 'fake_news_trainer', 'fake_news_transform']).
# INFO:absl:User module package has hash fingerprint version 21b7143bb664e0ef25e97060c4b3d952f2566cbaeebe6b9dcc0ba4cfb2ec4b37.
# INFO:absl:Executing: ['C:\\Users\\BPS\\.conda\\envs\\a443-churn\\python.exe', 'C:\\Users\\BPS\\AppData\\Local\\Temp\\tmpp_l7e5p8\\_tfx_generated_setup.py', 'bdist_wheel', '--bdist-dir', 'C:\\Users\\BPS\\AppData\\Local\\Temp\\tmpn5na48tn', '--dist-dir', 'C:\\Users\\BPS\\AppData\\Local\\Temp\\tmphpvou1dg']
# INFO:absl:Successfully built user code wheel distribution at 'output\\gesang_wibawono-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+21b7143bb664e0ef25e97060c4b3d952f2566cbaeebe6b9dcc0ba4cfb2ec4b37-py3-none-any.whl'; target user module is 'fake_news_trainer'.
# INFO:absl:Full user module path is 'fake_news_trainer@output\\gesang_wibawono-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+21b7143bb664e0ef25e97060c4b3d952f2566cbaeebe6b9dcc0ba4cfb2ec4b37-py3-none-any.whl'
# INFO:absl:Using deployment config:
#  executor_specs {
#   key: "CsvExampleGen"
#   value {
#     beam_executable_spec {
#       python_executor_spec {
#         class_path: "tfx.components.example_gen.csv_example_gen.executor.Executor"
#       }
#     }
#   }
# }
# executor_specs {
#   key: "Evaluator"
#   value {
#     beam_executable_spec {
#       python_executor_spec {
#         class_path: "tfx.components.evaluator.executor.Executor"
#       }
#     }
#   }
# }
# executor_specs {
#   key: "ExampleValidator"
#   value {
#     python_class_executable_spec {
#       class_path: "tfx.components.example_validator.executor.Executor"
#     }
#   }
# }
# executor_specs {
#   key: "Pusher"
#   value {
#     python_class_executable_spec {
#       class_path: "tfx.components.pusher.executor.Executor"
#     }
#   }
# }
# executor_specs {
#   key: "SchemaGen"
#   value {
#     python_class_executable_spec {
#       class_path: "tfx.components.schema_gen.executor.Executor"
#     }
#   }
# }
# executor_specs {
#   key: "StatisticsGen"
#   value {
#     beam_executable_spec {
#       python_executor_spec {
#         class_path: "tfx.components.statistics_gen.executor.Executor"
#       }
#     }
#   }
# }
# executor_specs {
#   key: "Trainer"
#   value {
#     python_class_executable_spec {
#       class_path: "tfx.components.trainer.executor.GenericExecutor"
#     }
#   }
# }
# executor_specs {
#   key: "Transform"
#   value {
#     beam_executable_spec {
#       python_executor_spec {
#         class_path: "tfx.components.transform.executor.Executor"
#       }
#     }
#   }
# }
# custom_driver_specs {
#   key: "CsvExampleGen"
#   value {
#     python_class_executable_spec {
#       class_path: "tfx.components.example_gen.driver.FileBasedDriver"
#     }
#   }
# }
# metadata_connection_config {
#   database_connection_config {
#     sqlite {
#       filename_uri: "output\\gesang_wibawono-pipeline\\metadata.sqlite"
#       connection_mode: READWRITE_OPENCREATE
#     }
#   }
# }
#
# INFO:absl:Using connection config:
#  sqlite {
#   filename_uri: "output\\gesang_wibawono-pipeline\\metadata.sqlite"
#   connection_mode: READWRITE_OPENCREATE
# }
#
# INFO:absl:Node CsvExampleGen depends on [].
# INFO:absl:Node CsvExampleGen is scheduled.
# INFO:absl:Node Latest_blessed_model_resolver depends on [].
# INFO:absl:Node Latest_blessed_model_resolver is scheduled.
# INFO:absl:Node StatisticsGen depends on ['Run[CsvExampleGen]'].
# INFO:absl:Node StatisticsGen is scheduled.
# INFO:absl:Node SchemaGen depends on ['Run[StatisticsGen]'].
# INFO:absl:Node SchemaGen is scheduled.
# INFO:absl:Node ExampleValidator depends on ['Run[SchemaGen]', 'Run[StatisticsGen]'].
# INFO:absl:Node ExampleValidator is scheduled.
# INFO:absl:Node Transform depends on ['Run[CsvExampleGen]', 'Run[SchemaGen]'].
# INFO:absl:Node Transform is scheduled.
# INFO:absl:Node Trainer depends on ['Run[SchemaGen]', 'Run[Transform]'].
# INFO:absl:Node Trainer is scheduled.
# INFO:absl:Node Evaluator depends on ['Run[CsvExampleGen]', 'Run[Latest_blessed_model_resolver]', 'Run[Trainer]'].
# INFO:absl:Node Evaluator is scheduled.
# INFO:absl:Node Pusher depends on ['Run[Evaluator]', 'Run[Trainer]'].
# INFO:absl:Node Pusher is scheduled.
# INFO:absl:node Latest_blessed_model_resolver is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.dsl.components.common.resolver.Resolver"
#   }
#   id: "Latest_blessed_model_resolver"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "gesang_wibawono-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20231120-153057.594609"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "gesang_wibawono-pipeline.Latest_blessed_model_resolver"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "_generated_model_3"
#     value {
#       channels {
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "gesang_wibawono-pipeline"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#       }
#       hidden: true
#     }
#   }
#   inputs {
#     key: "_generated_modelblessing_4"
#     value {
#       channels {
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "gesang_wibawono-pipeline"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ModelBlessing"
#           }
#         }
#       }
#       hidden: true
#     }
#   }
#   inputs {
#     key: "model"
#     value {
#       input_graph_ref {
#         graph_id: "graph_1"
#         key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "model_blessing"
#     value {
#       input_graph_ref {
#         graph_id: "graph_1"
#         key: "model_blessing"
#       }
#     }
#   }
#   input_graphs {
#     key: "graph_1"
#     value {
#       nodes {
#         key: "dict_2"
#         value {
#           output_data_type: ARTIFACT_MULTIMAP
#           dict_node {
#             node_ids {
#               key: "model"
#               value: "input_3"
#             }
#             node_ids {
#               key: "model_blessing"
#               value: "input_4"
#             }
#           }
#         }
#       }
#       nodes {
#         key: "input_3"
#         value {
#           output_data_type: ARTIFACT_LIST
#           input_node {
#             input_key: "_generated_model_3"
#           }
#         }
#       }
#       nodes {
#         key: "input_4"
#         value {
#           output_data_type: ARTIFACT_LIST
#           input_node {
#             input_key: "_generated_modelblessing_4"
#           }
#         }
#       }
#       nodes {
#         key: "op_1"
#         value {
#           output_data_type: ARTIFACT_MULTIMAP
#           op_node {
#             op_type: "tfx.dsl.input_resolution.strategies.latest_blessed_model_strategy.LatestBlessedModelStrategy"
#             args {
#               node_id: "dict_2"
#             }
#           }
#         }
#       }
#       result_node: "op_1"
#     }
#   }
# }
# downstream_nodes: "Evaluator"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# INFO:absl:Running as an resolver node.
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:[Latest_blessed_model_resolver] Resolved inputs: ({'model': [], 'model_blessing': []},)
# INFO:absl:node Latest_blessed_model_resolver is finished.
# INFO:absl:node CsvExampleGen is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.example_gen.csv_example_gen.component.CsvExampleGen"
#   }
#   id: "CsvExampleGen"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "gesang_wibawono-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20231120-153057.594609"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "gesang_wibawono-pipeline.CsvExampleGen"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "examples"
#     value {
#       artifact_spec {
#         type {
#           name: "Examples"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#           properties {
#             key: "version"
#             value: INT
#           }
#           base_type: DATASET
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "input_base"
#     value {
#       field_value {
#         string_value: "data"
#       }
#     }
#   }
#   parameters {
#     key: "input_config"
#     value {
#       field_value {
#         string_value: "{\n  \"splits\": [\n    {\n      \"name\": \"single_split\",\n      \"pattern\": \"*\"\n    }\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "output_config"
#     value {
#       field_value {
#         string_value: "{\n  \"split_config\": {\n    \"splits\": [\n      {\n        \"hash_buckets\": 8,\n        \"name\": \"train\"\n      },\n      {\n        \"hash_buckets\": 2,\n        \"name\": \"eval\"\n      }\n    ]\n  }\n}"
#       }
#     }
#   }
#   parameters {
#     key: "output_data_format"
#     value {
#       field_value {
#         int_value: 6
#       }
#     }
#   }
#   parameters {
#     key: "output_file_format"
#     value {
#       field_value {
#         int_value: 5
#       }
#     }
#   }
# }
# downstream_nodes: "Evaluator"
# downstream_nodes: "StatisticsGen"
# downstream_nodes: "Transform"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:[CsvExampleGen] Resolved inputs: ({},)
# INFO:absl:select span and version = (0, None)
# INFO:absl:latest span and version = (0, None)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 2
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=2, input_dict={}, output_dict=defaultdict(<class 'list'>, {'examples': [Artifact(artifact: uri: "output\\gesang_wibawono-pipeline\\CsvExampleGen\\examples\\2"
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:single_split,num_files:1,total_bytes:4507953,xor_checksum:1700469047,sum_checksum:1700469047"
#   }
# }
# custom_properties {
#   key: "span"
#   value {
#     int_value: 0
#   }
# }
# , artifact_type: name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )]}), exec_properties={'output_config': '{\n  "split_config": {\n    "splits": [\n      {\n        "hash_buckets": 8,\n        "name": "train"\n      },\n      {\n        "hash_buckets": 2,\n        "name": "eval"\n      }\n    ]\n  }\n}', 'output_file_format': 5, 'input_config': '{\n  "splits": [\n    {\n      "name": "single_split",\n      "pattern": "*"\n    }\n  ]\n}', 'output_data_format': 6, 'input_base': 'data', 'span': 0, 'version': None, 'input_fingerprint': 'split:single_split,num_files:1,total_bytes:4507953,xor_checksum:1700469047,sum_checksum:1700469047'}, execution_output_uri='output\\gesang_wibawono-pipeline\\CsvExampleGen\\.system\\executor_execution\\2\\executor_output.pb', stateful_working_dir='output\\gesang_wibawono-pipeline\\CsvExampleGen\\.system\\stateful_working_dir\\20231120-153057.594609', tmp_dir='output\\gesang_wibawono-pipeline\\CsvExampleGen\\.system\\executor_execution\\2\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.example_gen.csv_example_gen.component.CsvExampleGen"
#   }
#   id: "CsvExampleGen"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "gesang_wibawono-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20231120-153057.594609"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "gesang_wibawono-pipeline.CsvExampleGen"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "examples"
#     value {
#       artifact_spec {
#         type {
#           name: "Examples"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#           properties {
#             key: "version"
#             value: INT
#           }
#           base_type: DATASET
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "input_base"
#     value {
#       field_value {
#         string_value: "data"
#       }
#     }
#   }
#   parameters {
#     key: "input_config"
#     value {
#       field_value {
#         string_value: "{\n  \"splits\": [\n    {\n      \"name\": \"single_split\",\n      \"pattern\": \"*\"\n    }\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "output_config"
#     value {
#       field_value {
#         string_value: "{\n  \"split_config\": {\n    \"splits\": [\n      {\n        \"hash_buckets\": 8,\n        \"name\": \"train\"\n      },\n      {\n        \"hash_buckets\": 2,\n        \"name\": \"eval\"\n      }\n    ]\n  }\n}"
#       }
#     }
#   }
#   parameters {
#     key: "output_data_format"
#     value {
#       field_value {
#         int_value: 6
#       }
#     }
#   }
#   parameters {
#     key: "output_file_format"
#     value {
#       field_value {
#         int_value: 5
#       }
#     }
#   }
# }
# downstream_nodes: "Evaluator"
# downstream_nodes: "StatisticsGen"
# downstream_nodes: "Transform"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "gesang_wibawono-pipeline"
# , pipeline_run_id='20231120-153057.594609')
# INFO:absl:Generating examples.
# INFO:absl:Processing input csv data data\* to TFExample.
# INFO:absl:MetadataStore with DB connection initialized
# ERROR:absl:Execution 2 failed.
# INFO:absl:Cleaning up stateless execution info.
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.SimpleInvoker.invoke_process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common._OutputHandler.handle_process_outputs()
#
# ~\.conda\envs\a443-churn\lib\site-packages\tfx_bsl\coders\csv_decoder.py in process(self, csv_line)
#     171               csv_line: CSVLine) -> Iterable[Tuple[List[CSVCell], CSVLine]]:
# --> 172     line = self._reader.ReadLine(csv_line)
#     173     yield (line, csv_line)
#
# ~\.conda\envs\a443-churn\lib\site-packages\tfx_bsl\coders\csv_decoder.py in ReadLine(self, csv_line)
#     448     self._line_iterator.SetItem(csv_line)
# --> 449     return [cell.encode() for cell in next(self._reader)]
#     450
#
# Error: field larger than field limit (131072)
#
# During handling of the above exception, another exception occurred:
#
# Error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16992\420574087.py in <cell line: 15>()
#      13
#      14 pipeline = init_local_pipeline(components, pipeline_root)
# ---> 15 BeamDagRunner().run(pipeline=pipeline)
#
# ~\.conda\envs\a443-churn\lib\site-packages\tfx\orchestration\portable\tfx_runner.py in run(self, pipeline, run_options, **kwargs)
#     122     else:
#     123       run_options_pb = None
# --> 124     return self.run_with_ir(pipeline_pb, run_options=run_options_pb, **kwargs)
#
# ~\.conda\envs\a443-churn\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in run_with_ir(self, pipeline, run_options)
#     295                       pipeline=pipeline),
#     296                   *[beam.pvalue.AsIter(s) for s in signals_to_wait]))
# --> 297           logging.info('Node %s is scheduled.', node_id)
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in __exit__(self, exc_type, exc_val, exc_tb)
#     598     try:
#     599       if not exc_type:
# --> 600         self.result = self.run()
#     601         self.result.wait_until_finish()
#     602     finally:
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in run(self, test_runner_api)
#     575         finally:
#     576           shutil.rmtree(tmpdir)
# --> 577       return self.runner.run_pipeline(self, self._options)
#     578     finally:
#     579       if not is_in_ipython():
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\direct\direct_runner.py in run_pipeline(self, pipeline, options)
#     129       runner = BundleBasedDirectRunner()
#     130
# --> 131     return runner.run_pipeline(pipeline, options)
#     132
#     133
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in run_pipeline(self, pipeline, options)
#     200         options.view_as(pipeline_options.ProfilingOptions))
#     201
# --> 202     self._latest_run_result = self.run_via_runner_api(
#     203         pipeline.to_runner_api(default_environment=self._default_environment),
#     204         options)
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in run_via_runner_api(self, pipeline_proto, options)
#     222       pipeline_proto = self.embed_default_docker_image(pipeline_proto)
#     223     stage_context, stages = self.create_stages(pipeline_proto)
# --> 224     return self.run_stages(stage_context, stages)
#     225
#     226   def embed_default_docker_image(self, pipeline_proto):
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in run_stages(self, stage_context, stages)
#     453
#     454           bundle_counter += 1
# --> 455           bundle_results = self._execute_bundle(
#     456               runner_execution_context, bundle_context_manager, bundle_input)
#     457
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in _execute_bundle(self, runner_execution_context, bundle_context_manager, bundle_input)
#     781
#     782     last_result, deferred_inputs, newly_set_timers, watermark_updates = (
# --> 783         self._run_bundle(
#     784             runner_execution_context,
#     785             bundle_context_manager,
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in _run_bundle(self, runner_execution_context, bundle_context_manager, bundle_input, data_output, expected_timer_output, bundle_manager)
#    1010         expected_timer_output)
#    1011
# -> 1012     result, splits = bundle_manager.process_bundle(
#    1013         data_input, data_output, input_timers, expected_timer_output)
#    1014     # Now we collect all the deferred inputs remaining from bundle execution.
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in process_bundle(self, inputs, expected_outputs, fired_timers, expected_output_timers, dry_run)
#    1346             process_bundle_descriptor.id,
#    1347             cache_tokens=[next(self._cache_token_generator)]))
# -> 1348     result_future = self._worker_handler.control_conn.push(process_bundle_req)
#    1349
#    1350     split_results = []  # type: List[beam_fn_api_pb2.ProcessBundleSplitResponse]
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\worker_handlers.py in push(self, request)
#     377       self._uid_counter += 1
#     378       request.instruction_id = 'control_%s' % self._uid_counter
# --> 379     response = self.worker.do_instruction(request)
#     380     return ControlFuture(request.instruction_id, response)
#     381
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\sdk_worker.py in do_instruction(self, request)
#     622     if request_type:
#     623       # E.g. if register is set, this will call self.register(request.register))
# --> 624       return getattr(self, request_type)(
#     625           getattr(request, request_type), request.instruction_id)
#     626     else:
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\sdk_worker.py in process_bundle(self, request, instruction_id)
#     660         with self.maybe_profile(instruction_id):
#     661           delayed_applications, requests_finalization = (
# --> 662               bundle_processor.process_bundle(instruction_id))
#     663           monitoring_infos = bundle_processor.monitoring_infos()
#     664           response = beam_fn_api_pb2.InstructionResponse(
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\bundle_processor.py in process_bundle(self, instruction_id)
#    1060                   element.timer_family_id, timer_data)
#    1061           elif isinstance(element, beam_fn_api_pb2.Elements.Data):
# -> 1062             input_op_by_transform_id[element.transform_id].process_encoded(
#    1063                 element.data)
#    1064
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\bundle_processor.py in process_encoded(self, encoded_windowed_values)
#     230       decoded_value = self.windowed_coder_impl.decode_from_stream(
#     231           input_stream, True)
# --> 232       self.output(decoded_value)
#     233
#     234   def monitoring_infos(self, transform_id, tag_to_pcollection_id):
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.Operation.output()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.Operation.output()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.SimpleInvoker.invoke_process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common._OutputHandler.handle_process_outputs()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common._OutputHandler._write_value_to_tag()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.SimpleInvoker.invoke_process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common._OutputHandler.handle_process_outputs()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common._OutputHandler._write_value_to_tag()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.GeneralPurposeConsumerSet.receive()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.SimpleInvoker.invoke_process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in process(self, element, *signals)
#      88
#      89     logging.info('node %s is running.', self._node_id)
# ---> 90     self._run_node()
#      91     logging.info('node %s is finished.', self._node_id)
#      92
#
# ~\.conda\envs\a443-churn\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in _run_node(self)
#      97       with metadata.Metadata(self._mlmd_connection_config) as mlmd_handle:
#      98         partial_run_utils.snapshot(mlmd_handle, self._pipeline)
# ---> 99     launcher.Launcher(
#     100         pipeline_node=self._pipeline_node,
#     101         mlmd_connection=metadata.Metadata(self._mlmd_connection_config),
#
# ~\.conda\envs\a443-churn\lib\site-packages\tfx\orchestration\portable\launcher.py in launch(self)
#     571               executor_watcher.address)
#     572           executor_watcher.start()
# --> 573         executor_output = self._run_executor(execution_info)
#     574       except Exception as e:  # pylint: disable=broad-except
#     575         execution_output = (
#
# ~\.conda\envs\a443-churn\lib\site-packages\tfx\orchestration\portable\launcher.py in _run_executor(self, execution_info)
#     446     outputs_utils.make_output_dirs(execution_info.output_dict)
#     447     try:
# --> 448       executor_output = self._executor_operator.run_executor(execution_info)
#     449       code = executor_output.execution_result.code
#     450       if code != 0:
#
# ~\.conda\envs\a443-churn\lib\site-packages\tfx\orchestration\portable\beam_executor_operator.py in run_executor(self, execution_info, make_beam_pipeline_fn)
#     110         make_beam_pipeline_fn=make_beam_pipeline_fn)
#     111     executor = self._executor_cls(context=context)
# --> 112     return python_executor_operator.run_with_executor(execution_info, executor)
#
# ~\.conda\envs\a443-churn\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py in run_with_executor(execution_info, executor)
#      56
#      57   output_dict = copy.deepcopy(execution_info.output_dict)
# ---> 58   result = executor.Do(execution_info.input_dict, output_dict,
#      59                        execution_info.exec_properties)
#      60   if not result:
#
# ~\.conda\envs\a443-churn\lib\site-packages\tfx\components\example_gen\base_example_gen_executor.py in Do(self, input_dict, output_dict, exec_properties)
#     281       # pylint: disable=expression-not-assigned, no-value-for-parameter
#     282       for split_name, example_split in example_splits.items():
# --> 283         (example_split
#     284          | 'WriteSplit[{}]'.format(split_name) >> write_split.WriteSplit(
#     285              artifact_utils.get_split_uri(
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in __exit__(self, exc_type, exc_val, exc_tb)
#     598     try:
#     599       if not exc_type:
# --> 600         self.result = self.run()
#     601         self.result.wait_until_finish()
#     602     finally:
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in run(self, test_runner_api)
#     575         finally:
#     576           shutil.rmtree(tmpdir)
# --> 577       return self.runner.run_pipeline(self, self._options)
#     578     finally:
#     579       if not is_in_ipython():
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\direct\direct_runner.py in run_pipeline(self, pipeline, options)
#     129       runner = BundleBasedDirectRunner()
#     130
# --> 131     return runner.run_pipeline(pipeline, options)
#     132
#     133
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in run_pipeline(self, pipeline, options)
#     200         options.view_as(pipeline_options.ProfilingOptions))
#     201
# --> 202     self._latest_run_result = self.run_via_runner_api(
#     203         pipeline.to_runner_api(default_environment=self._default_environment),
#     204         options)
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in run_via_runner_api(self, pipeline_proto, options)
#     222       pipeline_proto = self.embed_default_docker_image(pipeline_proto)
#     223     stage_context, stages = self.create_stages(pipeline_proto)
# --> 224     return self.run_stages(stage_context, stages)
#     225
#     226   def embed_default_docker_image(self, pipeline_proto):
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in run_stages(self, stage_context, stages)
#     453
#     454           bundle_counter += 1
# --> 455           bundle_results = self._execute_bundle(
#     456               runner_execution_context, bundle_context_manager, bundle_input)
#     457
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in _execute_bundle(self, runner_execution_context, bundle_context_manager, bundle_input)
#     781
#     782     last_result, deferred_inputs, newly_set_timers, watermark_updates = (
# --> 783         self._run_bundle(
#     784             runner_execution_context,
#     785             bundle_context_manager,
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in _run_bundle(self, runner_execution_context, bundle_context_manager, bundle_input, data_output, expected_timer_output, bundle_manager)
#    1010         expected_timer_output)
#    1011
# -> 1012     result, splits = bundle_manager.process_bundle(
#    1013         data_input, data_output, input_timers, expected_timer_output)
#    1014     # Now we collect all the deferred inputs remaining from bundle execution.
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in process_bundle(self, inputs, expected_outputs, fired_timers, expected_output_timers, dry_run)
#    1346             process_bundle_descriptor.id,
#    1347             cache_tokens=[next(self._cache_token_generator)]))
# -> 1348     result_future = self._worker_handler.control_conn.push(process_bundle_req)
#    1349
#    1350     split_results = []  # type: List[beam_fn_api_pb2.ProcessBundleSplitResponse]
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\worker_handlers.py in push(self, request)
#     377       self._uid_counter += 1
#     378       request.instruction_id = 'control_%s' % self._uid_counter
# --> 379     response = self.worker.do_instruction(request)
#     380     return ControlFuture(request.instruction_id, response)
#     381
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\sdk_worker.py in do_instruction(self, request)
#     622     if request_type:
#     623       # E.g. if register is set, this will call self.register(request.register))
# --> 624       return getattr(self, request_type)(
#     625           getattr(request, request_type), request.instruction_id)
#     626     else:
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\sdk_worker.py in process_bundle(self, request, instruction_id)
#     660         with self.maybe_profile(instruction_id):
#     661           delayed_applications, requests_finalization = (
# --> 662               bundle_processor.process_bundle(instruction_id))
#     663           monitoring_infos = bundle_processor.monitoring_infos()
#     664           response = beam_fn_api_pb2.InstructionResponse(
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\bundle_processor.py in process_bundle(self, instruction_id)
#    1060                   element.timer_family_id, timer_data)
#    1061           elif isinstance(element, beam_fn_api_pb2.Elements.Data):
# -> 1062             input_op_by_transform_id[element.transform_id].process_encoded(
#    1063                 element.data)
#    1064
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\bundle_processor.py in process_encoded(self, encoded_windowed_values)
#     230       decoded_value = self.windowed_coder_impl.decode_from_stream(
#     231           input_stream, True)
# --> 232       self.output(decoded_value)
#     233
#     234   def monitoring_infos(self, transform_id, tag_to_pcollection_id):
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.Operation.output()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.Operation.output()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.SimpleInvoker.invoke_process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common._OutputHandler.handle_process_outputs()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common._OutputHandler._write_value_to_tag()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.SimpleInvoker.invoke_process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common._OutputHandler.handle_process_outputs()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common._OutputHandler._write_value_to_tag()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.SimpleInvoker.invoke_process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common._OutputHandler.handle_process_outputs()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common._OutputHandler._write_value_to_tag()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.SimpleInvoker.invoke_process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common._OutputHandler.handle_process_outputs()
#
# ~\.conda\envs\a443-churn\lib\site-packages\tfx_bsl\coders\csv_decoder.py in process(self, csv_line)
#     170   def process(self,
#     171               csv_line: CSVLine) -> Iterable[Tuple[List[CSVCell], CSVLine]]:
# --> 172     line = self._reader.ReadLine(csv_line)
#     173     yield (line, csv_line)
#     174
#
# ~\.conda\envs\a443-churn\lib\site-packages\tfx_bsl\coders\csv_decoder.py in ReadLine(self, csv_line)
#     447     """Reads out bytes for PY2 and Unicode for PY3."""
#     448     self._line_iterator.SetItem(csv_line)
# --> 449     return [cell.encode() for cell in next(self._reader)]
#     450
#     451   def __getstate__(self):
#
# Error: field larger than field limit (131072) [while running 'InputToRecord/ParseCSVLine']

# %%
# !pip freeze >> requirements.txt
